# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /root/.kaggle
# !cp -f /content/drive/MyDrive/ml/hacks/kaggle.json /root/.kaggle/kaggle.json
# !sudo apt install pv
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   doc-base
# The following NEW packages will be installed:
#   pv
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 48.3 kB of archives.
# After this operation, 123 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 pv amd64 1.6.6-1 [48.3 kB]
# Fetched 48.3 kB in 0s (129 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# ...

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f train_jpg_0.zip
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/train_jpg_0.zip -d /content/drive/MyDrive/ml/hacks/avito/data/images/ | awk 'BEGIN {ORS=" "} {if(NR%100==0)print NR"\n"}'

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f train_jpg_1.zip
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/train_jpg_1.zip -d /content/drive/MyDrive/ml/hacks/avito/data/images/ | awk 'BEGIN {ORS=" "} {if(NR%100==0)print NR"\n"}'

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f train_jpg_2.zip
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/train_jpg_2.zip -d /content/drive/MyDrive/ml/hacks/avito/data/images/ | awk 'BEGIN {ORS=" "} {if(NR%100==0)print NR"\n"}'

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f train_jpg_3.zip
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/train_jpg_3.zip -d /content/drive/MyDrive/ml/hacks/avito/data/images/ | awk 'BEGIN {ORS=" "} {if(NR%100==0)print NR"\n"}'

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f train_jpg_4.zip
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/train_jpg_4.zip -d /content/drive/MyDrive/ml/hacks/avito/data/images/ | awk 'BEGIN {ORS=" "} {if(NR%100==0)print NR"\n"}'

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f test.csv
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/test.csv.zip -d /content/drive/MyDrive/ml/hacks/avito/data
# !rm -f /content/drive/MyDrive/ml/hacks/avito/data/test.csv.zip
# Out:
# test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  /content/drive/MyDrive/ml/hacks/avito/data/test.csv.zip
#   inflating: /content/drive/MyDrive/ml/hacks/avito/data/test.csv

# %%
# !kaggle competitions download -c avito-demand-prediction -p /content/drive/MyDrive/ml/hacks/avito/data/ -f test_active.csv
# !unzip /content/drive/MyDrive/ml/hacks/avito/data/test_active.csv.zip -d /content/drive/MyDrive/ml/hacks/avito/data
# !rm -f /content/drive/MyDrive/ml/hacks/avito/data/test_active.csv.zip
# Out:
# ...
# 100% 2.45G/2.46G [00:42<00:00, 55.2MB/s]
# 100% 2.46G/2.46G [00:42<00:00, 61.7MB/s]
# Archive:  /content/drive/MyDrive/ml/hacks/avito/data/test_active.csv.zip
#   inflating: /content/drive/MyDrive/ml/hacks/avito/data/test_active.csv

# %%
# !mkdir images
# !for file in `ls /content/drive/MyDrive/ml/hacks/avito/data/images/ | head -n 10`; do cp /content/drive/MyDrive/ml/hacks/avito/data/images/$file ./images;done
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
import pandas as pd
pd.read_csv('/content/drive/MyDrive/ml/hacks/avito/data/train.csv',nrows=1000).to_csv('train.csv', header=True,index=False)
pd.read_csv('/content/drive/MyDrive/ml/hacks/avito/data/test.csv',nrows=1000).to_csv('test.csv', header=True,index=False)
pd.read_csv('/content/drive/MyDrive/ml/hacks/avito/data/train_active.csv',nrows=1000).to_csv('train_active.csv', header=True,index=False)
pd.read_csv('/content/drive/MyDrive/ml/hacks/avito/data/test_active.csv',nrows=1000).to_csv('test_active.csv', header=True,index=False)
